# %% [markdown]
# ## 1. Installing and Import Dependencies

# %%
# !pip install pixellib
# Out:
# Collecting pixellib
#   Using cached pixellib-0.7.1-py3-none-any.whl (430 kB)
# Collecting fvcore
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cloudpickle
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting tqdm
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting imgaug
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Requirement already satisfied: termcolor in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from pixellib) (2.2.0)
# Requirement already satisfied: pillow in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from pixellib) (9.4.0)
# Collecting black
#   Downloading black-23.1.0-cp37-cp37m-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 6.2 MB/s eta 0:00:00
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting future
#   Using cached future-0.18.3.tar.gz (840 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: opencv-python in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from pixellib) (4.7.0.68)
# Collecting yacs
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting imantics
#   Using cached imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting omegaconf
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 8.1 MB/s eta 0:00:00
# Collecting iopath
#   Using cached iopath-0.1.10.tar.gz (42 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting hydra-core
#   Using cached hydra_core-1.3.1-py3-none-any.whl (154 kB)
# Requirement already satisfied: matplotlib in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from pixellib) (3.5.3)
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.3-py3-none-any.whl (18 kB)
# Collecting pyQt5
#   Downloading PyQt5-5.15.9-cp37-abi3-win_amd64.whl (6.8 MB)
#      ---------------------------------------- 6.8/6.8 MB 6.3 MB/s eta 0:00:00
# Collecting Cython
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Collecting tomli>=1.1.0
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.4-cp37-cp37m-win_amd64.whl (160 kB)
#      -------------------------------------- 160.9/160.9 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from black->pixellib) (4.4.0)
# Collecting click>=8.0.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting pathspec>=0.9.0
#   Using cached pathspec-0.11.0-py3-none-any.whl (29 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting platformdirs>=2
#   Downloading platformdirs-3.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=22.0 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from black->pixellib) (23.0)
# Requirement already satisfied: numpy in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from fvcore->pixellib) (1.21.6)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
#      -------------------------------------- 153.2/153.2 kB 4.5 MB/s eta 0:00:00
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting importlib-resources
#   Using cached importlib_resources-5.10.2-py3-none-any.whl (34 kB)
# Collecting lxml
#   Downloading lxml-4.9.2-cp37-cp37m-win_amd64.whl (3.8 MB)
#      ---------------------------------------- 3.8/3.8 MB 7.0 MB/s eta 0:00:00
# Collecting xmljson
#   Using cached xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: scipy in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from imgaug->pixellib) (1.7.3)
# Collecting imageio
#   Using cached imageio-2.25.0-py3-none-any.whl (3.4 MB)
# Requirement already satisfied: six in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from imgaug->pixellib) (1.16.0)
# Collecting Shapely
#   Downloading shapely-2.0.1-cp37-cp37m-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 6.3 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ------------------------------------- 178.9/178.9 kB 10.5 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 6.8 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 7.4 MB/s eta 0:00:00
# Collecting sahi>=0.8.19
#   Using cached sahi-0.11.11-py3-none-any.whl (94 kB)
# Collecting jsonschema>=2.6.0
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from matplotlib->pixellib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from matplotlib->pixellib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from matplotlib->pixellib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from matplotlib->pixellib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from matplotlib->pixellib) (1.4.4)
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 50.1/50.1 MB 7.6 MB/s eta 0:00:00
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.1-cp37-cp37m-win_amd64.whl (77 kB)
#      ---------------------------------------- 77.5/77.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from tqdm->pixellib) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from click>=8.0.0->black->pixellib) (4.11.4)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp37-cp37m-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.6/62.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (22.2.0)
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from importlib-resources->hydra-core->pixellib) (3.12.0)
# Collecting terminaltables
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting fire
#   Using cached fire-0.5.0.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.28.2)
# Collecting click>=8.0.0
#   Using cached click-8.0.4-py3-none-any.whl (97 kB)
# Collecting pybboxes==0.1.6
#   Using cached pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from portalocker->iopath->pixellib) (305)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrut\miniconda3\envs\works\lib\site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.0.1)
# Building wheels for collected packages: future, fvcore, iopath, antlr4-python3-runtime, imantics, fire
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492055 sha256=50ea20c6ff29ef4b411ca55de746b0f0a17e47ddce266d00d9108e3b43948e02
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\fa\cd\1f\c6b7b50b564983bf3011e8fc75d06047ddc50c07f6e3660b00
#   Building wheel for fvcore (setup.py): started
#   Building wheel for fvcore (setup.py): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61417 sha256=f8fddf948bbb7966c6e8944d89ab0044db3ba4c92e3141b62bbf17ecbcbab405
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\af\cd\23\3fb62ec8606cb08cc18abb8d67bec255baf353623be889da1e
#   Building wheel for iopath (setup.py): started
#   Building wheel for iopath (setup.py): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31542 sha256=50442e58aeb736392480f3501996d553098baf4150a16ef7c3d19d993f5b4434
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\aa\cc\ed\ca4e88beef656b01c84b9185196513ef2faf74a5a379b043a7
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=c1c650f64b68cfbfe7fdb6bfb34737ebdbed05a0e03dce893f664305bebf3b9a
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\8b\8d\53\2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for imantics (setup.py): started
#   Building wheel for imantics (setup.py): finished with status 'done'
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16031 sha256=3a10bca544d82a3c79ca5daf9d13cccd5097050e1f677a5eec752e6a5b0943c1
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\da\7c\3e\296fe3ed4eb3bd713e91dee0d0549f12f316d49939a64bdc96
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116947 sha256=e9fc85b17a858008bf186e383616c14722b6f511d21f1bee65baf68ee6100d77
#   Stored in directory: c:\users\shrut\appdata\local\pip\cache\wheels\20\97\e1\dd2c472bebcdcaa85fdc07d0f19020299f1c86773028860c53
# Successfully built future fvcore iopath antlr4-python3-runtime imantics fire
# Installing collected packages: xmljson, PyQt5-Qt5, dataclasses, antlr4-python3-runtime, typed-ast, tqdm, tomli, tifffile, terminaltables, tabulate, Shapely, pyyaml, PyWavelets, pyrsistent, PyQt5-sip, pydot, pybboxes, portalocker, platformdirs, pkgutil-resolve-name, pathspec, networkx, mypy-extensions, lxml, importlib-resources, imageio, future, fire, Cython, cloudpickle, yacs, scikit-image, pyQt5, omegaconf, jsonschema, iopath, imantics, click, sahi, imgaug, hydra-core, fvcore, black, labelme2coco, pixellib
# Successfully installed Cython-0.29.33 PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.1 PyWavelets-1.3.0 Shapely-2.0.1 antlr4-python3-runtime-4.9.3 black-23.1.0 click-8.0.4 cloudpickle-2.2.1 dataclasses-0.6 fire-0.5.0 future-0.18.3 fvcore-0.1.5.post20221221 hydra-core-1.3.1 imageio-2.25.0 imantics-0.1.12 imgaug-0.4.0 importlib-resources-5.10.2 iopath-0.1.10 jsonschema-4.17.3 labelme2coco-0.2.3 lxml-4.9.2 mypy-extensions-1.0.0 networkx-2.6.3 omegaconf-2.3.0 pathspec-0.11.0 pixellib-0.7.1 pkgutil-resolve-name-1.3.10 platformdirs-3.0.0 portalocker-2.7.0 pyQt5-5.15.9 pybboxes-0.1.6 pydot-1.4.2 pyrsistent-0.19.3 pyyaml-6.0 sahi-0.11.11 scikit-image-0.19.3 tabulate-0.9.0 terminaltables-3.1.10 tifffile-2021.11.2 tomli-2.0.1 tqdm-4.64.1 typed-ast-1.5.4 xmljson-0.2.1 yacs-0.1.8

# %%
import pixellib
import cv2
import matplotlib.pyplot as plt
from pixellib.instance import instance_segmentation

# %% [markdown]
# ## 2. Setting up the Model

# %%
segmentation_model = instance_segmentation()
segmentation_model.load_model('mask_rcnn_coco.h5')
# Out:
# WARNING:tensorflow:From C:\Users\shrut\miniconda3\envs\works\lib\site-packages\tensorflow\python\util\deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %% [markdown]
# ## 3. Real Time Capture

# %%
cap = cv2.VideoCapture('Selfie.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    # Apply instance segmentation
    res = segmentation_model.segmentFrame(frame, show_bboxes=True)
    image = res[1]
    
    cv2.imshow('Instance Segmentation', image)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
# result
plt.imshow(image);
